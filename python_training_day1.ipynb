# %% [markdown]
# <a href="https://colab.research.google.com/github/SajidPatel78/python/blob/main/python_training_day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 50

print(a , "is a type of" , type(a))
# Out:
# 50 is a type of <class 'int'>

# %%
a = 20.0

print(a , "is a type of" , type(a))
# Out:
# 20.0 is a type of <class 'float'>
